# %% [markdown]
# # Examining Data on US K-12 Education

# %% [markdown]
# ## Final Project for Python for Data Science Applications (EN.553.287)

# %% [markdown]
# ## Rena Liu

# %% [markdown]
# ### I Finding and Cleaning Data Set

# %% [markdown]
# Dataset taken from Kaggle, titled "U.S. Education Datasets: Unification Project
# K-12 financial, enrollment, and achievement data in one place" and uploaded by Roy Garrard.
# Link: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %%
#import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Read in file, setting index to the Primary_Key given
data = pd.read_csv('states_all.csv', index_col = 'PRIMARY_KEY')

# Removed some columns and NaNs
data = data.drop(['GRADES_12_G', 'GRADES_9_12_G','GRADES_1_8_G', 'GRADES_PK_G', 'GRADES_KG_G', 'GRADES_ALL_G'],1)
data = data.dropna()
display(data)
# Out:
#                                           STATE  YEAR     ENROLL  \
# PRIMARY_KEY
# 1996_ALABAMA                            ALABAMA  1996   735912.0
# 1996_ARIZONA                            ARIZONA  1996   764681.0
# 1996_ARKANSAS                          ARKANSAS  1996   452907.0
# 1996_CALIFORNIA                      CALIFORNIA  1996  5460484.0
# 1996_COLORADO                          COLORADO  1996   655679.0
# 1996_CONNECTICUT                    CONNECTICUT  1996   499815.0
# 1996_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1996    79802.0
# 1996_FLORIDA                            FLORIDA  1996  2175352.0
# 1996_HAWAII                              HAWAII  1996   187104.0
# 1996_IOWA                                  IOWA  1996   502343.0
# 1996_KENTUCKY                          KENTUCKY  1996   639531.0
# 1996_LOUISIANA                        LOUISIANA  1996   796087.0
# 1996_MAINE                                MAINE  1996   213601.0
# ...

# %% [markdown]
# ### II Elementary Data Analysis

# %% [markdown]
# Overall Mean and Standard Deviaion: This is helpful as it gives us a general summary of the center and spread of each distribution of each column/category/label of data: enrollment, revenue, expenditure, and test scores.

# %%
# Computing and printing the mean and std each column
mean = pd.DataFrame(data.mean(0))
std = pd.DataFrame(data.std(0))
print("Means")
display(mean)
print("Standard Devs")
display(std)
# Out:
# Means
#                                          0
# YEAR                          2.007514e+03
# ENROLL                        9.414834e+05
# TOTAL_REVENUE                 1.047713e+07
# FEDERAL_REVENUE               9.431232e+05
# STATE_REVENUE                 4.850565e+06
# LOCAL_REVENUE                 4.683441e+06
# TOTAL_EXPENDITURE             1.058376e+07
# INSTRUCTION_EXPENDITURE       5.471180e+06
# SUPPORT_SERVICES_EXPENDITURE  3.092248e+06
# OTHER_EXPENDITURE             4.794490e+05
# CAPITAL_OUTLAY_EXPENDITURE    1.034431e+06
# GRADES_4_G                    7.214941e+04
# GRADES_8_G                    7.276652e+04
# AVG_MATH_4_SCORE              2.365956e+02
# AVG_MATH_8_SCORE              2.795360e+02
# AVG_READING_4_SCORE           2.193129e+02
# AVG_READING_8_SCORE           2.635418e+02
# Standard Devs
#                                          0
# YEAR                          5.287839e+00
# ENROLL                        1.120275e+06
# ...

# %% [markdown]
# Overall Minimum and Maximum and Indices: This is helpful as it gives us the minimum and maximum and respective state+year it is associated with of each distribution of each column/category/label of data: enrollment, revenue, expenditure, and test scores.

# %%
print("Max Enrollment of", np.max(data.ENROLL), "students was in", np.argmax(data.ENROLL))
print("Min Enrollment of", np.min(data.ENROLL), "students was in", np.argmin(data.ENROLL))
print("Max Revenue of $", np.max(data.TOTAL_REVENUE), "was in", np.argmax(data.TOTAL_REVENUE))
print("Min Revenue of $", np.min(data.TOTAL_REVENUE), "was in", np.argmin(data.TOTAL_REVENUE))
print("Max Expenditure of $", np.max(data.TOTAL_EXPENDITURE), "was in", np.argmax(data.TOTAL_EXPENDITURE))
print("Min Expenditure of $", np.min(data.TOTAL_EXPENDITURE), "was in", np.argmin(data.TOTAL_EXPENDITURE))
print("Max Avg 4th Grade Math Score was", np.max(data.AVG_MATH_4_SCORE), "in", np.argmax(data.AVG_MATH_4_SCORE))
print("Min Avg 4th Grade Math Score was", np.min(data.AVG_MATH_4_SCORE), "in", np.argmin(data.AVG_MATH_4_SCORE))
print("Max Avg 8th Grade Math Score was", np.max(data.AVG_MATH_8_SCORE), "in", np.argmax(data.AVG_MATH_8_SCORE))
print("Min Avg 8th Grade Math Score was", np.min(data.AVG_MATH_8_SCORE), "in", np.argmin(data.AVG_MATH_8_SCORE))
# Out:
# Max Enrollment of 6307022.0 students was in 2005_CALIFORNIA
# Min Enrollment of 44179.0 students was in 2013_DISTRICT_OF_COLUMBIA
# Max Revenue of $ 78248042.0 was in 2015_CALIFORNIA
# Min Revenue of $ 664057.0 was in 1996_WYOMING
# Max Expenditure of $ 78365958.0 was in 2015_CALIFORNIA
# Min Expenditure of $ 676305.0 was in 1996_WYOMING
# Max Avg 4th Grade Math Score was 253.420961133202 in 2013_MINNESOTA
# Min Avg 4th Grade Math Score was 187.134669958413 in 1996_DISTRICT_OF_COLUMBIA
# Max Avg 8th Grade Math Score was 300.568235011147 in 2013_MASSACHUSETTS
# Min Avg 8th Grade Math Score was 232.831509532896 in 1996_DISTRICT_OF_COLUMBIA

# %% [markdown]
# #### GroupBy

# %%
#Mean of Each Label over the Years for Each State
mean_by_state = data.groupby('STATE').apply(np.mean)
display(mean_by_state.drop(columns = 'YEAR'))

#Mean of Each Label for Each Year
mean_by_year = data.groupby('YEAR').apply(np.mean)
display(mean_by_year.drop(columns = 'YEAR'))
# Out:
#                             ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# STATE
# ALABAMA               7.376371e+05   6.169652e+06     6.773753e+05
# ALASKA                1.316934e+05   2.115601e+06     3.203439e+05
# ARIZONA               9.065474e+05   7.339271e+06     8.964081e+05
# ARKANSAS              4.663763e+05   4.107712e+06     4.747310e+05
# CALIFORNIA            6.121856e+06   6.271606e+07     6.877971e+06
# COLORADO              7.915762e+05   7.540133e+06     5.673329e+05
# CONNECTICUT           5.303273e+05   8.358386e+06     4.014933e+05
# DELAWARE              1.165334e+05   1.684968e+06     1.273024e+05
# DISTRICT_OF_COLUMBIA  5.605300e+04   1.049973e+06     1.281373e+05
# FLORIDA               2.587087e+06   2.374379e+07     2.658313e+06
# GEORGIA               1.601999e+06   1.615629e+07     1.520288e+06
# HAWAII                1.829921e+05   2.240808e+06     2.436497e+05
# IDAHO                 2.612904e+05   1.925244e+06     2.061480e+05
# ...

# %% [markdown]
# ### III Special Pandas

# %%
#def entropy(ser):
#    return np.sum(ser*np.log2(ser))

GROUPBY
NEW COL
percentage rev from fed, state, local
percentage expenditure on instruction, support_services, other, captial outlay
max and min of all time percentages, compare this with num students and score

PIVOT TABLES
#data.pivot_table(values='ALC_AGE',aggfunc=[np.mean,np.std],index='EMP',columns='CIG_EVER')
math and reading score vs expenditure on instruction, support_services

TIMESERIES? MULTIINDEX? ROLLING WINDOWS?

# %% [markdown]
# Why each calculation/analysis was done

# %% [markdown]
# ### IV Matplotlib

# %%
#spending on instruction, support services, other, and capital outlay over the years for AL, CA, MaS, WY 
#revenue from fed, state, local over the years for AL, CA, MaS, WY
#Scores over the years for AL, CA, MaS, WY

#Change between 4th grade scores and 8th grade scores 4yrs later with change in rev and spending

#for AL, CA, MS, WY, breakdown of expenditures, scores over the years (2 axis)
#for states, expenditure vs num students
#score vs expenditure/num students

#np.corrcoef(INSTRUCTION_EXPENDITURE, AVG_MATH_4_SCORE)

# %% [markdown]
# What the plot shows, why useful, how make money

# %% [markdown]
# ### V Plotting

# %% [markdown]
# ### VI Sklearn

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
#predict 4th grade math scores
X = data.drop(columns = ['STATE','AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE','AVG_READING_4_SCORE', 'AVG_READING_8_SCORE'])
y = data.AVG_MATH_4_SCORE
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
#Convert ys from continuous to multiclass

from sklearn import preprocessing
from sklearn import utils

lab_enc = preprocessing.LabelEncoder()
encodedYTrain = lab_enc.fit_transform(y_train)
print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(encodedYTrain))

encodedYTest = lab_enc.fit_transform(y_test)
print(utils.multiclass.type_of_target(y_test))
print(utils.multiclass.type_of_target(encodedYTest))
# Out:
# continuous
# multiclass
# continuous
# multiclass

# %%
#fit on training data
clf.fit(X_train, encodedYTrain)

#predict test
preds = clf.predict(X_test)
print((preds == y_test).mean())

#measure performance
print(clf.score(X_test,encodedYTest))

#See if overfit
print(clf.score(X_train,encodedYTrain))
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 0.0
# 0.0
# 0.9358974358974359
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
